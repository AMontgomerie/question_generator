# %% [markdown]
# # Question Generator command line example

# %% [markdown]
# First we need to install HuggingFace's transformers library.

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/27/3c/91ed8f5c4e7ef3227b4119200fc0ed4b4fd965b1f0172021c25701087825/transformers-3.0.2-py3-none-any.whl (769kB)
#      |████████████████████████████████| 778kB 7.5MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.4)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 12.9MB/s
# Collecting sentencepiece!=0.1.92
#   Downloading https://files.pythonhosted.org/packages/d4/a4/d0a884c4300004a78cca907a6ff9a5e9fe4f090f5d95ab341c53d28cbc58/sentencepiece-0.1.91-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 43.3MB/s
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers==0.8.1.rc1
#   Downloading https://files.pythonhosted.org/packages/40/d0/30d5f8d221a0ed981a186c8eb986ce1c94e3a6e87f994eae9f4aa5250217/tokenizers-0.8.1rc1-cp36-cp36m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 60.5MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=8d7631df49d501aa94ec9b49c38e7aecb3262e285c3b4b79579d74d3b204745f
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sacremoses, sentencepiece, tokenizers, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.91 tokenizers-0.8.1rc1 transformers-3.0.2

# %% [markdown]
# Next we're going to clone the github repo.

# %%
# !git clone https://github.com/amontgomerie/question_generator
# %cd question_generator/
# Out:
# Cloning into 'question_generator'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 80 (delta 36), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (80/80), done.
# /content/question_generator

# %% [markdown]
# Make sure that we're using the GPU:

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
assert device == torch.device('cuda'), "Not using CUDA. Set: Runtime > Change runtime type > Hardware Accelerator: GPU"

# %% [markdown]
# Finally we can run question generation script using the following arguments:
# ```
# --text_dir # the directory of the artice to use as context
# --num_questions # the number of questions to be generated (default 10)
# --answer_style # can be 'all', 'sentences', or 'multiple_choice' (default 'all')
# --show_answers # set to 'False' to hide answers (default 'True')
# --use_qa_eval # use to turn off the question filtering 'True'/'False' (default True)
# ```

# %%
# !python 'run_qg.py' --text_dir 'articles/twitter_hack.txt'
# Out:
# 2020-07-29 10:27:43.887842: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Downloading: 100% 1.21k/1.21k [00:00<00:00, 1.02MB/s]
# Downloading: 100% 792k/792k [00:00<00:00, 1.60MB/s]
# Downloading: 100% 39.0/39.0 [00:00<00:00, 33.6kB/s]
# Downloading: 100% 121/121 [00:00<00:00, 99.2kB/s]
# Downloading: 100% 25.0/25.0 [00:00<00:00, 16.2kB/s]
# Downloading: 100% 892M/892M [00:12<00:00, 69.7MB/s]
# Downloading: 100% 482/482 [00:00<00:00, 407kB/s]
# Downloading: 100% 213k/213k [00:00<00:00, 760kB/s]
# Downloading: 100% 112/112 [00:00<00:00, 30.4kB/s]
# Downloading: 100% 49.0/49.0 [00:00<00:00, 39.0kB/s]
# Downloading: 100% 433M/433M [00:06<00:00, 70.2MB/s]
# Generating questions...
#
# Evaluating QA pairs...
#
# 1) Q: Who said this was the worst hack of a major social media platform yet?
#    A: Dmitri Alperovitch, who co-founded cyber-security company CrowdStrike, told Reuters news agency: "This appears to be the worst hack of a major social media platform yet.
#
# 2) Q: What did Twitter say about the hack?
#    A: Twitter said the hackers had targeted its employees "with access to internal systems and tools".
#
# 3) Q: Who wrote to Twitter asking if he was vulnerable?
#    A: Republican Senator Josh Hawley has written to the company asking if President Trump's account had been vulnerable.
#
# 4) Q: What did Twitter say about the hack?
#    A: "We know they [the hackers] used this access to take control of many highly-visible (including verified) accounts and Tweet on their behalf," the company said in a series of tweets.
#
# 5) Q: What did the company say about the hack?
#    A: It added that "significant steps" had been taken to limit access to such internal systems and tools while the company's investigation continues.
#
# 6) Q: What did the UK's cyber security centre say?
#    A: The UK's National Cyber Security Centre said its officers had "reached out" to the tech firm.
#
# 7) Q: When did the committee demand that Twitter brief it?
#    A: " The US Senate Commerce committee has demanded Twitter brief it about Wednesday's incident by 23 July.
#
# 8) Q: How long ago was Jack Dorsey's account hacked?
#    A: 1. 23 July
#       2. Last year (correct)
#       3. 2017
#       4. 2020
#
# 9) Q: What was the problem with the password reset?
#    A: Password reset requests were also being denied and some other "account functions" disabled.
#
# 10) Q: What day did Cameron Winklevoss tweet a message?
#     A: 1. Wednesday (correct)
#        2. 23 July
#        3. November
#        4. Last year
